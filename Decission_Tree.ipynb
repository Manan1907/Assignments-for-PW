# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.metrics import r2_score
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
from sklearn.tree import export_graphviz
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
'''
Question 6:   Write a Python program to:
● Load the Iris Dataset
● Train a Decision Tree Classifier using the Gini criterion
● Print the model’s accuracy and feature importances
'''

# importing the dataset
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target variable (species)
feature_names = iris.feature_names

# Split the dataset into training and testing sets
# 80% for training, 20% for testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# Create a Decision Tree Classifier with Gini criterion
dtree = DecisionTreeClassifier(criterion='gini', random_state=1)

# Train the model
dtree.fit(X_train, y_train)

# Make predictions
y_pred = dtree.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

# Print feature importances
importances = dtree.feature_importances_
for i, feature_name in enumerate(feature_names):
    print(f"Feature '{feature_name}': {importances[i]}")
# Out:
# Accuracy: 0.9666666666666667
# Feature 'sepal length (cm)': 0.007520367662419047
# Feature 'sepal width (cm)': 0.01880091915604763
# Feature 'petal length (cm)': 0.07584565922951901
# Feature 'petal width (cm)': 0.8978330539520143

# %%
'''
Question 7:  Write a Python program to:
● Load the Iris Dataset
● Train a Decision Tree Classifier with max_depth=3 and compare its accuracy to a fully-grown tree.
'''

# importing the dataset
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target variable (species)

# Split the dataset into training and testing sets
# 80% for training, 20% for testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# Create a Decision Tree Classifier with Gini criterion
dtree = DecisionTreeClassifier(criterion='entropy') # Full Grown tree
dtree_purn = DecisionTreeClassifier(criterion='entropy', max_depth= 3,) # Max Depth of 3

# Train the model
dtree.fit(X_train, y_train)
dtree_purn.fit(X_train, y_train)

# Make predictions
y_pred = dtree.predict(X_test)
y_pred_purn = dtree.predict(X_test)

# Evaluate the model
accuracy_purn = accuracy_score(y_test, y_pred_purn)
accuracy = accuracy_score(y_test, y_pred)

# Print the results
print(f"Accuracy for complete tree: {accuracy}")
print(f"Accuracy for complete tree wuth max depth 3 : {accuracy_purn}")
# Out:
# Accuracy for complete tree: 0.9666666666666667
# Accuracy for complete tree wuth max depth 3 : 0.9666666666666667

# %%
'''
Question 8: Write a Python program to:
● Load the Boston Housing Dataset
● Train a Decision Tree Regressor
● Print the Mean Squared Error (MSE) and feature importances
'''

# importing the dataset
from sklearn.datasets import fetch_california_housing

# Load the California Housing dataset
housing = fetch_california_housing()
X = housing.data  # Features
y = housing.target  # Target variable (house value)
feature_names = housing.feature_names

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# Create a Decision Tree Regressor
regressor = DecisionTreeRegressor(random_state=1)

# Train the model
regressor.fit(X_train, y_train)

# Make predictions
y_pred = regressor.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")

# Print feature importances
importances = regressor.feature_importances_
for i, feature_name in enumerate(feature_names):
    print(f"Feature '{feature_name}': {importances[i]}")
# Out:
# Mean Squared Error: 0.495235205629094
# Feature 'MedInc': 0.5285090936963706
# Feature 'HouseAge': 0.05188353710616045
# Feature 'AveRooms': 0.05297496833123543
# Feature 'AveBedrms': 0.02866045788296106
# Feature 'Population': 0.030515676373806224
# Feature 'AveOccup': 0.13083767753210346
# Feature 'Latitude': 0.09371656401749287
# Feature 'Longitude': 0.08290202505986989

# %%
'''
Question 9: Write a Python program to:
● Load the Iris Dataset
● Tune the Decision Tree’s max_depth and min_samples_split using GridSearchCV
● Print the best parameters and the resulting model accuracy
'''

# importing the dataset
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target variable (species)


# Split the dataset into training and testing sets 80% for training, 20% for testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)


# Define the parameter grid
param_grid = {
    'max_depth': [2, 4, 6, 8, 10],
    'min_samples_split': [2, 5, 10, 15, 20]
}

# Create a Decision Tree classifier
dtree = DecisionTreeClassifier(random_state=1)

# Set up GridSearchCV
grid_search = GridSearchCV(dtree, param_grid, cv=5, scoring='accuracy', refit=True)

# Fit the grid search to the data
grid_search.fit(X_train, y_train)

# Get the best parameters and the best model
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

# Evaluate the best model on the test set
accuracy = best_model.score(X_test, y_test)

print("Best Parameters:", best_params)
print("Accuracy on Test Set:", accuracy)
# Out:
# Best Parameters: {'max_depth': 4, 'min_samples_split': 2}
# Accuracy on Test Set: 0.9666666666666667

# %%
'''
Question 10: Imagine you’re working as a data scientist for a healthcare company that wants to predict whether a patient has a certain disease. You have a large dataset with mixed data types and some missing values. Explain the step-by-step process you would follow to:
● Handle the missing values
● Encode the categorical features
● Train a Decision Tree model
● Tune its hyperparameters
● Evaluate its performance And describe what business value this model could provide in the real-world setting.
'''

# importing the dataset
df = sns.load_dataset('titanic')

#Handle the missing values

#Droping embark town as there are only 2 cases so droping 2 rows
df_subset = df.dropna(subset=['embark_town']).copy()

#Imputing deck with mode value
mode_value = df_subset[df_subset['deck'].notna()]['deck'].mode()[0]
#df_subset = df_subset['deck'].fillna(mode_value)


#Imputing age with mean value
df_subset.loc[:, 'age'] = df_subset['age'].fillna(df_subset['age'].mean())
df_subset.loc[:, 'deck'] = df_subset['deck'].fillna(df_subset['deck'].mode()[0])
#df_notna.shape
#print(df_subset.notna().sum())


#Encode the categorical features
df_subset = pd.get_dummies(df_subset, columns=['sex'], drop_first=True)
df_subset = pd.get_dummies(df_subset, columns=['embarked'], drop_first=True)
df_subset = pd.get_dummies(df_subset, columns=['deck'], drop_first=True)


# Train a Decision Tree model
x = df_subset.drop('survived', axis=1)
y = df_subset.iloc[:,0]

# Drop non-numeric columns before splitting
x = x.select_dtypes(include=np.number)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)


params = {
    'criterion': ["squared_error", "absolute_error", "friedman_mse", 'poisson'],
    'splitter': ["best", "random"],
    'max_depth': [1, 2, 3, 4, 10],
    'max_features':['sqrt', 'log2', None] # Removed 'auto'
}
regressor = DecisionTreeRegressor()
model = GridSearchCV(regressor, param_grid=params, cv=5, scoring='neg_mean_squared_error', verbose=3)
model.fit(x_train, y_train)

#Check the best model
model.best_params_

final_model = DecisionTreeRegressor(criterion = 'squared_error', max_depth = 4, max_features = 'log2', splitter = 'random')
final_model.fit(x_train, y_train)

y_pred = final_model.predict(x_test)
r2_score(y_pred, y_test)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [CV 1/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=best;, score=-0.228 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=best;, score=-0.200 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=best;, score=-0.202 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=best;, score=-0.225 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=best;, score=-0.225 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=random;, score=-0.212 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=random;, score=-0.200 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=random;, score=-0.233 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=random;, score=-0.239 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=1, max_features=sqrt, splitter=random;, score=-0.251 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=best;, score=-0.220 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=best;, score=-0.238 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=best;, score=-0.224 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=best;, score=-0.225 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=best;, score=-0.230 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=random;, score=-0.190 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=random;, score=-0.221 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=random;, score=-0.219 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=random;, score=-0.229 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=1, max_features=log2, splitter=random;, score=-0.251 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=1, max_features=None, splitter=best;, score=-0.220 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=1, max_features=None, splitter=best;, score=-0.207 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=1, max_features=None, splitter=best;, score=-0.202 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=1, max_features=None, splitter=best;, score=-0.239 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=1, max_features=None, splitter=best;, score=-0.230 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=1, max_features=None, splitter=random;, score=-0.190 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=1, max_features=None, splitter=random;, score=-0.205 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=1, max_features=None, splitter=random;, score=-0.202 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=1, max_features=None, splitter=random;, score=-0.241 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=1, max_features=None, splitter=random;, score=-0.230 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=best;, score=-0.195 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=best;, score=-0.201 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=best;, score=-0.208 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=best;, score=-0.230 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=best;, score=-0.217 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=random;, score=-0.209 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=random;, score=-0.234 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=random;, score=-0.202 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=random;, score=-0.227 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=sqrt, splitter=random;, score=-0.229 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=best;, score=-0.185 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=best;, score=-0.196 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=best;, score=-0.208 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=best;, score=-0.241 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=best;, score=-0.217 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=random;, score=-0.195 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=random;, score=-0.203 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=random;, score=-0.199 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=random;, score=-0.238 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=log2, splitter=random;, score=-0.230 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=None, splitter=best;, score=-0.214 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=None, splitter=best;, score=-0.193 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=None, splitter=best;, score=-0.195 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=None, splitter=best;, score=-0.230 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=None, splitter=best;, score=-0.217 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=None, splitter=random;, score=-0.194 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=None, splitter=random;, score=-0.191 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=None, splitter=random;, score=-0.205 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=None, splitter=random;, score=-0.238 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=None, splitter=random;, score=-0.223 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=best;, score=-0.207 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=best;, score=-0.195 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=best;, score=-0.184 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=best;, score=-0.216 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=best;, score=-0.211 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=random;, score=-0.205 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=random;, score=-0.218 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=random;, score=-0.221 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=random;, score=-0.236 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3, max_features=sqrt, splitter=random;, score=-0.226 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=best;, score=-0.220 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=best;, score=-0.196 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=best;, score=-0.188 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=best;, score=-0.216 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=best;, score=-0.215 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=random;, score=-0.192 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=random;, score=-0.230 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=random;, score=-0.176 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=random;, score=-0.232 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3, max_features=log2, splitter=random;, score=-0.248 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3, max_features=None, splitter=best;, score=-0.200 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3, max_features=None, splitter=best;, score=-0.191 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3, max_features=None, splitter=best;, score=-0.191 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3, max_features=None, splitter=best;, score=-0.226 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3, max_features=None, splitter=best;, score=-0.204 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=3, max_features=None, splitter=random;, score=-0.186 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=3, max_features=None, splitter=random;, score=-0.190 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=3, max_features=None, splitter=random;, score=-0.180 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=3, max_features=None, splitter=random;, score=-0.238 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=3, max_features=None, splitter=random;, score=-0.220 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.210 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.181 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.200 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.208 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.206 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=random;, score=-0.186 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=random;, score=-0.214 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=random;, score=-0.203 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=random;, score=-0.228 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=sqrt, splitter=random;, score=-0.232 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=best;, score=-0.198 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=best;, score=-0.194 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=best;, score=-0.202 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=best;, score=-0.224 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=best;, score=-0.214 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=random;, score=-0.190 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=random;, score=-0.198 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=random;, score=-0.213 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=random;, score=-0.230 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=log2, splitter=random;, score=-0.219 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=None, splitter=best;, score=-0.202 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=None, splitter=best;, score=-0.178 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=None, splitter=best;, score=-0.191 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=None, splitter=best;, score=-0.224 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=None, splitter=best;, score=-0.202 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=None, splitter=random;, score=-0.189 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=None, splitter=random;, score=-0.178 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=None, splitter=random;, score=-0.194 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=None, splitter=random;, score=-0.218 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=None, splitter=random;, score=-0.219 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.296 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.261 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.270 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.251 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.306 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.279 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.274 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.256 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.280 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.231 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=best;, score=-0.289 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=best;, score=-0.255 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=best;, score=-0.278 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=best;, score=-0.223 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=best;, score=-0.254 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=random;, score=-0.261 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=random;, score=-0.218 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=random;, score=-0.233 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=random;, score=-0.259 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=log2, splitter=random;, score=-0.232 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=None, splitter=best;, score=-0.322 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=None, splitter=best;, score=-0.282 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=None, splitter=best;, score=-0.234 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=None, splitter=best;, score=-0.304 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=None, splitter=best;, score=-0.284 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=None, splitter=random;, score=-0.245 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=None, splitter=random;, score=-0.267 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=None, splitter=random;, score=-0.230 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=None, splitter=random;, score=-0.233 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=None, splitter=random;, score=-0.288 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=best;, score=-0.273 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=best;, score=-0.373 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=best;, score=-0.317 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=best;, score=-0.387 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=best;, score=-0.359 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=random;, score=-0.273 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=random;, score=-0.373 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=random;, score=-0.289 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=random;, score=-0.366 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=1, max_features=sqrt, splitter=random;, score=-0.359 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=1, max_features=log2, splitter=best;, score=-0.350 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=1, max_features=log2, splitter=best;, score=-0.289 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=1, max_features=log2, splitter=best;, score=-0.317 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=1, max_features=log2, splitter=best;, score=-0.387 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=1, max_features=log2, splitter=best;, score=-0.359 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=1, max_features=log2, splitter=random;, score=-0.273 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=1, max_features=log2, splitter=random;, score=-0.373 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=1, max_features=log2, splitter=random;, score=-0.345 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=1, max_features=log2, splitter=random;, score=-0.331 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=1, max_features=log2, splitter=random;, score=-0.401 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=1, max_features=None, splitter=best;, score=-0.301 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=1, max_features=None, splitter=best;, score=-0.317 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=1, max_features=None, splitter=best;, score=-0.331 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=1, max_features=None, splitter=best;, score=-0.387 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=1, max_features=None, splitter=best;, score=-0.373 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=1, max_features=None, splitter=random;, score=-0.273 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=1, max_features=None, splitter=random;, score=-0.303 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=1, max_features=None, splitter=random;, score=-0.324 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=1, max_features=None, splitter=random;, score=-0.387 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=1, max_features=None, splitter=random;, score=-0.359 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=2, max_features=sqrt, splitter=best;, score=-0.252 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=2, max_features=sqrt, splitter=best;, score=-0.331 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=2, max_features=sqrt, splitter=best;, score=-0.331 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=2, max_features=sqrt, splitter=best;, score=-0.359 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=2, max_features=sqrt, splitter=best;, score=-0.380 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=2, max_features=sqrt, splitter=random;, score=-0.273 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=2, max_features=sqrt, splitter=random;, score=-0.338 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=2, max_features=sqrt, splitter=random;, score=-0.289 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=2, max_features=sqrt, splitter=random;, score=-0.444 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=2, max_features=sqrt, splitter=random;, score=-0.359 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=2, max_features=log2, splitter=best;, score=-0.301 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=2, max_features=log2, splitter=best;, score=-0.289 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=2, max_features=log2, splitter=best;, score=-0.246 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=2, max_features=log2, splitter=best;, score=-0.387 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=2, max_features=log2, splitter=best;, score=-0.373 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=2, max_features=log2, splitter=random;, score=-0.322 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=2, max_features=log2, splitter=random;, score=-0.303 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=2, max_features=log2, splitter=random;, score=-0.324 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=2, max_features=log2, splitter=random;, score=-0.387 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=2, max_features=log2, splitter=random;, score=-0.394 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=2, max_features=None, splitter=best;, score=-0.301 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=2, max_features=None, splitter=best;, score=-0.310 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=2, max_features=None, splitter=best;, score=-0.289 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=2, max_features=None, splitter=best;, score=-0.373 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=2, max_features=None, splitter=best;, score=-0.331 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=2, max_features=None, splitter=random;, score=-0.336 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=2, max_features=None, splitter=random;, score=-0.303 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=2, max_features=None, splitter=random;, score=-0.289 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=2, max_features=None, splitter=random;, score=-0.387 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=2, max_features=None, splitter=random;, score=-0.366 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=3, max_features=sqrt, splitter=best;, score=-0.301 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=3, max_features=sqrt, splitter=best;, score=-0.225 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=3, max_features=sqrt, splitter=best;, score=-0.232 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=3, max_features=sqrt, splitter=best;, score=-0.296 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=3, max_features=sqrt, splitter=best;, score=-0.331 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=3, max_features=sqrt, splitter=random;, score=-0.294 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=3, max_features=sqrt, splitter=random;, score=-0.303 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=3, max_features=sqrt, splitter=random;, score=-0.271 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=3, max_features=sqrt, splitter=random;, score=-0.387 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=3, max_features=sqrt, splitter=random;, score=-0.366 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=3, max_features=log2, splitter=best;, score=-0.266 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=3, max_features=log2, splitter=best;, score=-0.303 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=3, max_features=log2, splitter=best;, score=-0.239 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=3, max_features=log2, splitter=best;, score=-0.359 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=3, max_features=log2, splitter=best;, score=-0.324 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=3, max_features=log2, splitter=random;, score=-0.273 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=3, max_features=log2, splitter=random;, score=-0.324 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=3, max_features=log2, splitter=random;, score=-0.289 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=3, max_features=log2, splitter=random;, score=-0.415 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=3, max_features=log2, splitter=random;, score=-0.352 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=3, max_features=None, splitter=best;, score=-0.273 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=3, max_features=None, splitter=best;, score=-0.296 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=3, max_features=None, splitter=best;, score=-0.289 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=3, max_features=None, splitter=best;, score=-0.324 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=3, max_features=None, splitter=best;, score=-0.324 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=3, max_features=None, splitter=random;, score=-0.259 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=3, max_features=None, splitter=random;, score=-0.324 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=3, max_features=None, splitter=random;, score=-0.268 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=3, max_features=None, splitter=random;, score=-0.352 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=3, max_features=None, splitter=random;, score=-0.317 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.322 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.317 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.225 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.317 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=4, max_features=sqrt, splitter=best;, score=-0.345 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=4, max_features=sqrt, splitter=random;, score=-0.304 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=4, max_features=sqrt, splitter=random;, score=-0.310 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=4, max_features=sqrt, splitter=random;, score=-0.239 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=4, max_features=sqrt, splitter=random;, score=-0.343 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=4, max_features=sqrt, splitter=random;, score=-0.357 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=4, max_features=log2, splitter=best;, score=-0.259 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=4, max_features=log2, splitter=best;, score=-0.283 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=4, max_features=log2, splitter=best;, score=-0.269 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=4, max_features=log2, splitter=best;, score=-0.310 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=4, max_features=log2, splitter=best;, score=-0.317 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=4, max_features=log2, splitter=random;, score=-0.323 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=4, max_features=log2, splitter=random;, score=-0.331 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=4, max_features=log2, splitter=random;, score=-0.282 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=4, max_features=log2, splitter=random;, score=-0.417 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=4, max_features=log2, splitter=random;, score=-0.338 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=4, max_features=None, splitter=best;, score=-0.274 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=4, max_features=None, splitter=best;, score=-0.296 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=4, max_features=None, splitter=best;, score=-0.289 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=4, max_features=None, splitter=best;, score=-0.338 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=4, max_features=None, splitter=best;, score=-0.331 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=4, max_features=None, splitter=random;, score=-0.329 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=4, max_features=None, splitter=random;, score=-0.317 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=4, max_features=None, splitter=random;, score=-0.232 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=4, max_features=None, splitter=random;, score=-0.338 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=4, max_features=None, splitter=random;, score=-0.324 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.315 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.290 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.275 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.338 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=10, max_features=sqrt, splitter=best;, score=-0.352 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.252 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.312 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.255 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.329 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=10, max_features=sqrt, splitter=random;, score=-0.340 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=10, max_features=log2, splitter=best;, score=-0.309 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=10, max_features=log2, splitter=best;, score=-0.303 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=10, max_features=log2, splitter=best;, score=-0.246 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=10, max_features=log2, splitter=best;, score=-0.345 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=10, max_features=log2, splitter=best;, score=-0.324 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=10, max_features=log2, splitter=random;, score=-0.290 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=10, max_features=log2, splitter=random;, score=-0.319 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=10, max_features=log2, splitter=random;, score=-0.275 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=10, max_features=log2, splitter=random;, score=-0.310 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=10, max_features=log2, splitter=random;, score=-0.384 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=10, max_features=None, splitter=best;, score=-0.294 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=10, max_features=None, splitter=best;, score=-0.305 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=10, max_features=None, splitter=best;, score=-0.268 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=10, max_features=None, splitter=best;, score=-0.342 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=10, max_features=None, splitter=best;, score=-0.324 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_depth=10, max_features=None, splitter=random;, score=-0.294 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_depth=10, max_features=None, splitter=random;, score=-0.282 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_depth=10, max_features=None, splitter=random;, score=-0.299 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_depth=10, max_features=None, splitter=random;, score=-0.331 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_depth=10, max_features=None, splitter=random;, score=-0.313 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=1, max_features=sqrt, splitter=best;, score=-0.227 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=1, max_features=sqrt, splitter=best;, score=-0.200 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=1, max_features=sqrt, splitter=best;, score=-0.202 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=1, max_features=sqrt, splitter=best;, score=-0.232 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=1, max_features=sqrt, splitter=best;, score=-0.225 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=1, max_features=sqrt, splitter=random;, score=-0.201 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=1, max_features=sqrt, splitter=random;, score=-0.230 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=1, max_features=sqrt, splitter=random;, score=-0.202 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=1, max_features=sqrt, splitter=random;, score=-0.230 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=1, max_features=sqrt, splitter=random;, score=-0.249 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=1, max_features=log2, splitter=best;, score=-0.220 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=1, max_features=log2, splitter=best;, score=-0.238 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=1, max_features=log2, splitter=best;, score=-0.216 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=1, max_features=log2, splitter=best;, score=-0.239 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=1, max_features=log2, splitter=best;, score=-0.249 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=1, max_features=log2, splitter=random;, score=-0.228 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=1, max_features=log2, splitter=random;, score=-0.226 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=1, max_features=log2, splitter=random;, score=-0.205 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=1, max_features=log2, splitter=random;, score=-0.239 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=1, max_features=log2, splitter=random;, score=-0.240 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=1, max_features=None, splitter=best;, score=-0.220 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=1, max_features=None, splitter=best;, score=-0.207 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=1, max_features=None, splitter=best;, score=-0.202 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=1, max_features=None, splitter=best;, score=-0.239 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=1, max_features=None, splitter=best;, score=-0.230 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=1, max_features=None, splitter=random;, score=-0.209 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=1, max_features=None, splitter=random;, score=-0.205 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=1, max_features=None, splitter=random;, score=-0.205 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=1, max_features=None, splitter=random;, score=-0.239 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=1, max_features=None, splitter=random;, score=-0.230 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, splitter=best;, score=-0.185 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, splitter=best;, score=-0.226 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, splitter=best;, score=-0.200 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, splitter=best;, score=-0.238 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, splitter=best;, score=-0.223 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, splitter=random;, score=-0.193 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, splitter=random;, score=-0.218 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, splitter=random;, score=-0.205 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, splitter=random;, score=-0.224 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, splitter=random;, score=-0.235 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=best;, score=-0.223 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=best;, score=-0.232 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=best;, score=-0.195 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=best;, score=-0.227 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=best;, score=-0.215 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=random;, score=-0.213 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=random;, score=-0.208 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=random;, score=-0.224 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=random;, score=-0.240 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=log2, splitter=random;, score=-0.239 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=None, splitter=best;, score=-0.214 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=None, splitter=best;, score=-0.193 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=None, splitter=best;, score=-0.195 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=None, splitter=best;, score=-0.230 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=None, splitter=best;, score=-0.217 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=None, splitter=random;, score=-0.184 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=None, splitter=random;, score=-0.193 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=None, splitter=random;, score=-0.189 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=None, splitter=random;, score=-0.238 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=None, splitter=random;, score=-0.221 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=best;, score=-0.206 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=best;, score=-0.207 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=best;, score=-0.194 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=best;, score=-0.230 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=best;, score=-0.216 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=random;, score=-0.207 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=random;, score=-0.198 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=random;, score=-0.198 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=random;, score=-0.227 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3, max_features=sqrt, splitter=random;, score=-0.216 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=best;, score=-0.194 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=best;, score=-0.190 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=best;, score=-0.179 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=best;, score=-0.228 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=best;, score=-0.218 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=random;, score=-0.184 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=random;, score=-0.200 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=random;, score=-0.210 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=random;, score=-0.238 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3, max_features=log2, splitter=random;, score=-0.228 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3, max_features=None, splitter=best;, score=-0.200 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3, max_features=None, splitter=best;, score=-0.191 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3, max_features=None, splitter=best;, score=-0.191 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3, max_features=None, splitter=best;, score=-0.226 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3, max_features=None, splitter=best;, score=-0.204 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=3, max_features=None, splitter=random;, score=-0.191 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=3, max_features=None, splitter=random;, score=-0.200 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=3, max_features=None, splitter=random;, score=-0.194 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=3, max_features=None, splitter=random;, score=-0.228 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=3, max_features=None, splitter=random;, score=-0.222 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=best;, score=-0.203 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=best;, score=-0.207 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=best;, score=-0.199 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=best;, score=-0.209 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=best;, score=-0.217 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=random;, score=-0.194 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=random;, score=-0.203 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=random;, score=-0.197 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=random;, score=-0.225 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=4, max_features=sqrt, splitter=random;, score=-0.225 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=4, max_features=log2, splitter=best;, score=-0.203 total time=   0.0s
# ...
# [CV 5/5] END criterion=poisson, max_depth=1, max_features=sqrt, splitter=random;, score=-0.230 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=1, max_features=log2, splitter=best;, score=-0.220 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=1, max_features=log2, splitter=best;, score=-0.239 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=1, max_features=log2, splitter=best;, score=-0.202 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=1, max_features=log2, splitter=best;, score=-0.225 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=1, max_features=log2, splitter=best;, score=-0.230 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=1, max_features=log2, splitter=random;, score=-0.190 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=1, max_features=log2, splitter=random;, score=-0.233 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=1, max_features=log2, splitter=random;, score=-0.213 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=1, max_features=log2, splitter=random;, score=-0.225 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=1, max_features=log2, splitter=random;, score=-0.225 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=1, max_features=None, splitter=best;, score=-0.220 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=1, max_features=None, splitter=best;, score=-0.208 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=1, max_features=None, splitter=best;, score=-0.195 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=1, max_features=None, splitter=best;, score=-0.225 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=1, max_features=None, splitter=best;, score=-0.225 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=1, max_features=None, splitter=random;, score=-0.190 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=1, max_features=None, splitter=random;, score=-0.205 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=1, max_features=None, splitter=random;, score=-0.202 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=1, max_features=None, splitter=random;, score=-0.241 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=1, max_features=None, splitter=random;, score=-0.240 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=2, max_features=sqrt, splitter=best;, score=-0.194 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=2, max_features=sqrt, splitter=best;, score=-0.195 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=2, max_features=sqrt, splitter=best;, score=-0.200 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=2, max_features=sqrt, splitter=best;, score=-0.215 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=2, max_features=sqrt, splitter=best;, score=-0.218 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=2, max_features=sqrt, splitter=random;, score=-0.228 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=2, max_features=sqrt, splitter=random;, score=-0.202 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=2, max_features=sqrt, splitter=random;, score=-0.194 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=2, max_features=sqrt, splitter=random;, score=-0.238 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=2, max_features=sqrt, splitter=random;, score=-0.247 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=2, max_features=log2, splitter=best;, score=-0.211 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=2, max_features=log2, splitter=best;, score=-0.204 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=2, max_features=log2, splitter=best;, score=-0.185 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=2, max_features=log2, splitter=best;, score=-0.225 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=2, max_features=log2, splitter=best;, score=-0.216 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=2, max_features=log2, splitter=random;, score=-0.192 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=2, max_features=log2, splitter=random;, score=-0.203 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=2, max_features=log2, splitter=random;, score=-0.199 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=2, max_features=log2, splitter=random;, score=-0.231 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=2, max_features=log2, splitter=random;, score=-0.251 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=2, max_features=None, splitter=best;, score=-0.214 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=2, max_features=None, splitter=best;, score=-0.190 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=2, max_features=None, splitter=best;, score=-0.202 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=2, max_features=None, splitter=best;, score=-0.225 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=2, max_features=None, splitter=best;, score=-0.218 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=2, max_features=None, splitter=random;, score=-0.202 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=2, max_features=None, splitter=random;, score=-0.205 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=2, max_features=None, splitter=random;, score=-0.203 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=2, max_features=None, splitter=random;, score=-0.226 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=2, max_features=None, splitter=random;, score=-0.224 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=3, max_features=sqrt, splitter=best;, score=-0.199 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=3, max_features=sqrt, splitter=best;, score=-0.210 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=3, max_features=sqrt, splitter=best;, score=-0.191 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=3, max_features=sqrt, splitter=best;, score=-0.229 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=3, max_features=sqrt, splitter=best;, score=-0.211 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=3, max_features=sqrt, splitter=random;, score=-0.191 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=3, max_features=sqrt, splitter=random;, score=-0.204 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=3, max_features=sqrt, splitter=random;, score=-0.208 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=3, max_features=sqrt, splitter=random;, score=-0.236 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=3, max_features=sqrt, splitter=random;, score=-0.210 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=3, max_features=log2, splitter=best;, score=-0.224 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=3, max_features=log2, splitter=best;, score=-0.197 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=3, max_features=log2, splitter=best;, score=-0.207 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=3, max_features=log2, splitter=best;, score=-0.228 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=3, max_features=log2, splitter=best;, score=-0.217 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=3, max_features=log2, splitter=random;, score=-0.185 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=3, max_features=log2, splitter=random;, score=-0.194 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=3, max_features=log2, splitter=random;, score=-0.192 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=3, max_features=log2, splitter=random;, score=-0.208 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=3, max_features=log2, splitter=random;, score=-0.230 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=3, max_features=None, splitter=best;, score=-0.218 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=3, max_features=None, splitter=best;, score=-0.205 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=3, max_features=None, splitter=best;, score=-0.208 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=3, max_features=None, splitter=best;, score=-0.223 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=3, max_features=None, splitter=best;, score=-0.212 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=3, max_features=None, splitter=random;, score=-0.196 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=3, max_features=None, splitter=random;, score=-0.200 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=3, max_features=None, splitter=random;, score=-0.192 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=3, max_features=None, splitter=random;, score=-0.234 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=3, max_features=None, splitter=random;, score=-0.223 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=4, max_features=sqrt, splitter=best;, score=-0.195 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=4, max_features=sqrt, splitter=best;, score=-0.207 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=4, max_features=sqrt, splitter=best;, score=-0.199 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=4, max_features=sqrt, splitter=best;, score=-0.214 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=4, max_features=sqrt, splitter=best;, score=-0.210 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=4, max_features=sqrt, splitter=random;, score=-0.185 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=4, max_features=sqrt, splitter=random;, score=-0.186 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=4, max_features=sqrt, splitter=random;, score=-0.184 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=4, max_features=sqrt, splitter=random;, score=-0.214 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=4, max_features=sqrt, splitter=random;, score=-0.214 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=4, max_features=log2, splitter=best;, score=-0.197 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=4, max_features=log2, splitter=best;, score=-0.196 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=4, max_features=log2, splitter=best;, score=-0.180 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=4, max_features=log2, splitter=best;, score=-0.226 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=4, max_features=log2, splitter=best;, score=-0.211 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=4, max_features=log2, splitter=random;, score=-0.196 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=4, max_features=log2, splitter=random;, score=-0.196 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=4, max_features=log2, splitter=random;, score=-0.208 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=4, max_features=log2, splitter=random;, score=-0.234 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=4, max_features=log2, splitter=random;, score=-0.238 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=4, max_features=None, splitter=best;, score=-0.209 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=4, max_features=None, splitter=best;, score=-0.202 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=4, max_features=None, splitter=best;, score=-0.199 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=4, max_features=None, splitter=best;, score=-0.224 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=4, max_features=None, splitter=best;, score=-0.201 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=4, max_features=None, splitter=random;, score=-0.185 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=4, max_features=None, splitter=random;, score=-0.200 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=4, max_features=None, splitter=random;, score=-0.189 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=4, max_features=None, splitter=random;, score=-0.229 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=4, max_features=None, splitter=random;, score=-0.221 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=10, max_features=sqrt, splitter=best;, score=-0.234 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=10, max_features=sqrt, splitter=best;, score=-0.250 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=10, max_features=sqrt, splitter=best;, score=-0.244 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=10, max_features=sqrt, splitter=best;, score=-0.209 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=10, max_features=sqrt, splitter=best;, score=-0.258 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=10, max_features=sqrt, splitter=random;, score=-0.248 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=10, max_features=sqrt, splitter=random;, score=-0.207 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=10, max_features=sqrt, splitter=random;, score=-0.221 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=10, max_features=sqrt, splitter=random;, score=-0.236 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=10, max_features=sqrt, splitter=random;, score=-0.223 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=10, max_features=log2, splitter=best;, score=-0.261 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=10, max_features=log2, splitter=best;, score=-0.236 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=10, max_features=log2, splitter=best;, score=-0.229 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=10, max_features=log2, splitter=best;, score=-0.235 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=10, max_features=log2, splitter=best;, score=-0.235 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=10, max_features=log2, splitter=random;, score=-0.206 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=10, max_features=log2, splitter=random;, score=-0.224 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=10, max_features=log2, splitter=random;, score=-0.212 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=10, max_features=log2, splitter=random;, score=-0.207 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=10, max_features=log2, splitter=random;, score=-0.222 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=10, max_features=None, splitter=best;, score=-0.243 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=10, max_features=None, splitter=best;, score=-0.242 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=10, max_features=None, splitter=best;, score=-0.244 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=10, max_features=None, splitter=best;, score=-0.246 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=10, max_features=None, splitter=best;, score=-0.268 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=10, max_features=None, splitter=random;, score=-0.268 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=10, max_features=None, splitter=random;, score=-0.209 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=10, max_features=None, splitter=random;, score=-0.215 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=10, max_features=None, splitter=random;, score=-0.251 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=10, max_features=None, splitter=random;, score=-0.242 total time=   0.0s
# -3.5547291537662877
